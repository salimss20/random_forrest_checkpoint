# %% [markdown]
# ## DECISION TREE ALGORITHM

# %% [markdown]
# ## 1.data preprocessing

# %%
import pandas as pd
titanic_df = pd.read_csv("titanic-passengers.csv",sep=";")
titanic_df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
titanic_df["Age"].fillna(titanic_df["Age"].mean(),inplace=True)
titanic_df["Cabin"].fillna("G6",inplace=True) #replacing the missing value with G6
titanic_df["Embarked"].fillna("S",inplace=True) #replacing the missing value in Embarked
titanic_df.isnull().sum().sum()
# Out:
# 0

# %%
new_df=titanic_df
new_df['Title'] =titanic_df['Name'].str.split(',|\\.',expand = True)[1] 
new_df['Title'] =titanic_df['Title'].str.strip()
new_df['Title'].value_counts()
# Out:
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Mlle              2
# Col               2
# Major             2
# Don               1
# Lady              1
# Jonkheer          1
# Mme               1
# Sir               1
# Capt              1
# the Countess      1
# Ms                1
# Name: Title, dtype: int64

# %%
import pandas as pd
import numpy as np
dict={

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }

new_df['Title'] =new_df['Title'].map(dict)
new_df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
new_df['Title'].value_counts()
# Out:
# Mrs        643
# Miss       185
# Master      40
# Officer     18
# Royalty      5
# Name: Title, dtype: int64

# %%
#conversions
cleanup_nums={ "Sex" : {"female":0,"male":1}}
new_df.replace(cleanup_nums,inplace=True)
new_df["Sex"].value_counts()
# Out:
# 1    577
# 0    314
# Name: Sex, dtype: int64

# %%
cleanup_nums={ "Survived" : {"No":0,"Yes":1}}
new_df.replace(cleanup_nums,inplace=True)
new_df["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
dict1={"Mrs":0 , 
      "Miss": 1,
      "Master": 2,  
      "Officer":3,
      "Royalty": 4}
new_df['Title'] =new_df['Title'].map(dict1)
new_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# 4                               Davidson, Mr. Thornton    1  31.000000      1
# ...

# %% [markdown]
# ## 2.TREE DECISION MODEL

# %%
#importing relevant libraries
from sklearn.model_selection import train_test_split

# %%
x=new_df.drop(["Survived", "Name", "Cabin", "Ticket", "Embarked"], axis=1)
y= new_df["Survived"]

# %%
#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree  
from sklearn.metrics import accuracy_score
#applying tree algorithm
tree = tree.DecisionTreeClassifier()  
tree.fit(x_train, y_train)   #fitting our model
y_pred=tree.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7653631284916201

# %%
pip install graphviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## PLOT

# %%
conda install -c conda-forge python-graphviz
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import graphivz
dot_data=tree_export_graphivz(Classifier, outfile=None)
graph=graphivz.source(data_dot)
graph.render("new_df")
graph
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12272/507735821.py in <module>
# ----> 1 import graphivz
#       2 dot_data=tree_export_graphivz(Classifier, outfile=None)
#       3 graph=graphivz.source(data_dot)
#       4 graph.render("new_df")
#       5 graph
#
# ModuleNotFoundError: No module named 'graphivz'

# %% [markdown]
# ## 3. DIFFRENT PARAMETRES

# %%
new_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# 4                               Davidson, Mr. Thornton    1  31.000000      1
# ...

# %%
new_df["Embarked"].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
dict2={"S": 0, "C":1, "Q": 2}
new_df['Embarked']=new_df['Embarked'].map(dict2)
new_df["Embarked"].value_counts()
# Out:
# 0    646
# 1    168
# 2     77
# Name: Embarked, dtype: int64

# %%
x1=new_df.drop(["Survived", "Name", "Cabin", "Ticket", "Title","Age","Sex"], axis=1)
y1=new_df["Survived"]

# %%
#splitting data
x1_train, x1_test, y1_train, y1_test = train_test_split(x1,y1, test_size=0.20,random_state=10)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree  
from sklearn.metrics import accuracy_score
#applying tree algorithm
tree = tree.DecisionTreeClassifier()  
tree.fit(x1_train, y1_train)   #fitting our model
y1_pred=tree.predict(x1_test)   # evaluating our model
print("score:{}".format(accuracy_score(y1_test, y1_pred)))
# Out:
# score:0.7094972067039106

# %% [markdown]
# by dropping the SEX feature we can notice that the accuracy of the tree model has deacreased

# %% [markdown]
# ## RANDOM FOREST MODEL

# %%
from sklearn.ensemble import RandomForestClassifier #Importing Random Forest Classifier
from sklearn import metrics  # Importing metrics to test accuracy

clf=RandomForestClassifier(n_estimators=1000)  #Creating a random forest with 100 decision trees
clf.fit(x_train, y_train)  #Training our model
y_pred=clf.predict(x_test)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))  #Measuring the accuracy of our model
# Out:
# Accuracy: 0.8715083798882681

# %% [markdown]
# using a random forest model compared to a normal decison tree has encreased the accuracy of the classification because is uses the majority votes of multiple tree decisions combined (num of estimators)
